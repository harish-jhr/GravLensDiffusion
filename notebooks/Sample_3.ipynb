# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torch.nn.functional as F
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir("/content/drive/MyDrive/Hari/Evaluation/Diffusion/")
sys.path.append(os.path.abspath("src"))
print("Changed directory to:", os.getcwd())
from sample import sample
from sample2 import sample2
from sample3 import sample3
# Out:
# Changed directory to: /content/drive/MyDrive/Hari/Evaluation/Diffusion

# %%
from noise_scheduler import LinNoiseScheduler
from model_unet import Unet

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Load model with checkpoint
model = Unet(im_channels =1).to(device)
model.load_state_dict(torch.load("/content/drive/MyDrive/Hari/Evaluation/Diffusion/results/model_checkpoint.pth"))
model.eval()
# Create the noise scheduler
scheduler = LinNoiseScheduler(num_of_timesteps=1000,beta_start=0.0001,beta_end = 0.02)

# %% [markdown]
# This will generate 100 images , I need 10000 for a FID estimation. I plan to run this loop 100 times , I ca

# %%
with torch.no_grad():
  sample3(model, scheduler,0)
# Out:
# 15it [00:01,  7.92it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d633c372a473> in <cell line: 0>()
#       1 with torch.no_grad():
# ----> 2   sample3(model, scheduler,0)
#
# /content/drive/MyDrive/Hari/Evaluation/Diffusion/src/sample3.py in sample3(model, scheduler, run)
#      25
#      26         # Use scheduler to get x0 and xt-1
# ---> 27         xt, x0_pred = scheduler.sample_prev_timestep(xt, noise_pred, torch.as_tensor(i).to(device))
#      28
#      29         # Save x0
#
# KeyboardInterrupt:

# %%
for i in range(100):
  if i != 0:
    with torch.no_grad():
      sample3(model,scheduler,i)
# Out:
# 1000it [01:40,  9.93it/s]
# Successfully generated 100 images. This was the 2th run.
# 1000it [01:42,  9.77it/s]
# Successfully generated 100 images. This was the 3th run.
# 1000it [01:42,  9.80it/s]
# Successfully generated 100 images. This was the 4th run.
# 1000it [01:42,  9.75it/s]
# Successfully generated 100 images. This was the 5th run.
# 1000it [01:42,  9.79it/s]
# Successfully generated 100 images. This was the 6th run.
# 1000it [01:42,  9.78it/s]
# Successfully generated 100 images. This was the 7th run.
# 1000it [01:42,  9.79it/s]
# Successfully generated 100 images. This was the 8th run.
# 1000it [01:42,  9.78it/s]
# Successfully generated 100 images. This was the 9th run.
# 1000it [01:41,  9.81it/s]
# Successfully generated 100 images. This was the 10th run.
# 1000it [01:41,  9.83it/s]
# Successfully generated 100 images. This was the 11th run.
# 1000it [01:42,  9.79it/s]
# Successfully generated 100 images. This was the 12th run.
# 1000it [01:42,  9.80it/s]
# Successfully generated 100 images. This was the 13th run.
# 1000it [01:41,  9.81it/s]
# Successfully generated 100 images. This was the 14th run.
# 1000it [01:42,  9.80it/s]
# Successfully generated 100 images. This was the 15th run.
# 1000it [01:41,  9.82it/s]
# Successfully generated 100 images. This was the 16th run.
# 1000it [01:42,  9.77it/s]
# Successfully generated 100 images. This was the 17th run.
# 1000it [01:41,  9.81it/s]
# Successfully generated 100 images. This was the 18th run.
# 1000it [01:42,  9.80it/s]
# Successfully generated 100 images. This was the 19th run.
# 1000it [01:41,  9.82it/s]
# Successfully generated 100 images. This was the 20th run.
# 1000it [01:41,  9.81it/s]
# Successfully generated 100 images. This was the 21th run.
# 1000it [01:41,  9.82it/s]
# Successfully generated 100 images. This was the 22th run.
# 1000it [01:41,  9.83it/s]
# Successfully generated 100 images. This was the 23th run.
# 1000it [01:41,  9.81it/s]
# Successfully generated 100 images. This was the 24th run.
# 1000it [01:41,  9.83it/s]
# Successfully generated 100 images. This was the 25th run.
# 1000it [01:41,  9.85it/s]
# Successfully generated 100 images. This was the 26th run.
# 1000it [01:41,  9.82it/s]
# Successfully generated 100 images. This was the 27th run.
# 940it [01:34,  9.82it/s]
